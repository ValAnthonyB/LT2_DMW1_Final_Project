# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading the data

# %%
filepath = '../Data/shopping_dataset.xlsx'
df = pd.read_excel(filepath, nrows=52924, sheet_name='in')
df = df.iloc[:,1:]
df = df[['CustomerID', 'Transaction_Date', 'Product_SKU', 'Product_Description']]


df_ref = pd.read_csv('../Data/prod_categories.csv')

df = pd.merge(df, df_ref
             ,how='left'
             ,left_on='Product_Description'
             ,right_on='Product_Description')
df = df.drop(columns=['Product_Category'])

# replacing whitespaces
df['Predicted_Category'] = df['Predicted_Category'].str.replace(' ', '') 
df['Predicted_Category'] = df['Predicted_Category'].str.replace('&', 'and') 
df.head()
# Out:
#    CustomerID Transaction_Date     Product_SKU  \
# 0       17850       2019-01-01  GGOENEBJ079499
# 1       17850       2019-01-01  GGOENEBJ079499
# 2       17850       2019-01-01  GGOENEBQ078999
# 3       17850       2019-01-01  GGOENEBQ079099
# 4       17850       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Predicted_Category
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...     homeandkitchen
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...     homeandkitchen
# 2             Nest Cam Outdoor Security Camera - USA     homeandkitchen
# 3    Nest Protect Smoke + CO White Battery Alarm-USA     homeandkitchen
# 4  Nest Learning Thermostat 3rd Gen-USA - Stainle...     homeandkitchen

# %%
df['Predicted_Category'].unique()
# Out:
# array(['homeandkitchen', 'office', 'Tees', 'sportsandfitness',
#        'HoodiesandJackets', 'KidsApparel', 'CapsandHats', 'onesie',
#        'bagsandluggage', 'Drinkware', 'petsupplies', 'beautyandhealth',
#        'carandmotorbike', 'GiftCards'], dtype=object)

# %% [markdown]
# # We remove items that are very rarely bought since these will act as noise to the clustering algorithm

# %%
df = df[~df['Predicted_Category'].isin(['GiftCards' 
                                        ,'carandmotorbike' 
                                        ,'onesie'
                                        ,'homeandkitchen'
                                        ,'Tees'
                                        ,'office'
                                        #,'petsupplies'
                                       ])]
df.head()
# Out:
#       CustomerID Transaction_Date     Product_SKU  \
# 2172       17850       2019-01-01  GGOEGAPB058615
# 2174       17850       2019-01-01  GGOEYAFB073115
# 2179       12583       2019-01-01  GGOEGATB060415
# 2185       12583       2019-01-01  GGOEGAFJ036214
# 2186       12583       2019-01-01  GGOEGAYC068324
#
#                                Product_Description Predicted_Category
# 2172              Google Women's Yoga Jacket Black   sportsandfitness
# 2174             YouTube Men's Fleece Hoodie Black  HoodiesandJackets
# 2179   Google Women's Quilted Insulated Vest Black  HoodiesandJackets
# 2185             Google Men's Pullover Hoodie Grey  HoodiesandJackets
# 2186  Google Youth Short Sleeve T-shirt Royal Blue        KidsApparel

# %% [markdown]
# # Combining the categories bought by the customer

# %%
df_combined_categories = (
                            df
                            .groupby('CustomerID')
                            ['Predicted_Category']
                            .apply(lambda x: ' '.join(x))
                            .reset_index()
)
df_combined_categories.head()
# Out:
#    CustomerID                                 Predicted_Category
# 0       12347  KidsApparel HoodiesandJackets bagsandluggage b...
# 1       12348  KidsApparel KidsApparel sportsandfitness Drink...
# 2       12350  CapsandHats CapsandHats sportsandfitness Capsa...
# 3       12356  sportsandfitness KidsApparel KidsApparel Hoodi...
# 4       12359                                        CapsandHats

# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Apply TF-IDF vectorization
tfidf_matrix = tfidf_vectorizer.fit_transform(df_combined_categories['Predicted_Category'])

# Convert the TF-IDF matrix to a DataFrame for better readability
tfidf_df = pd.DataFrame(tfidf_matrix.toarray()
                        ,columns=tfidf_vectorizer.get_feature_names_out()
                        ,index=df_combined_categories['CustomerID'])
tfidf_df.head()
# Out:
#             bagsandluggage  beautyandhealth  capsandhats  drinkware  \
# CustomerID
# 12347             0.568189         0.000000     0.388631   0.463974
# 12348             0.000000         0.000000     0.000000   0.636778
# 12350             0.000000         0.000000     0.974051   0.000000
# 12356             0.203496         0.436919     0.000000   0.498515
# 12359             0.000000         0.000000     1.000000   0.000000
#
#             hoodiesandjackets  kidsapparel  petsupplies  sportsandfitness
# CustomerID
# 12347                0.366188     0.215148          0.0          0.361210
# 12348                0.000000     0.590556          0.0          0.495740
# 12350                0.000000     0.000000          0.0          0.226331
# 12356                0.393450     0.462330          0.0          0.388101
# 12359                0.000000     0.000000          0.0          0.000000

# %% [markdown]
# # Export the features

# %%
tfidf_df.to_parquet('../Data/features_tfidf_removed_categories.parquet.gz', compression='gzip')
